# %%
import chess.pgn
import pandas as pd

# File path to your PGN file
pgn_file_path = r"C:\Users\James\OneDrive\Desktop\GitHub\group4_project\raw_data\lichess_db_standard_rated_2013-01.pgn"
output_csv_path = "chess_games.csv"

# List to store game data
games = []




# Open the PGN file and process games
with open(pgn_file_path, "r", encoding="utf-8") as pgn_file:
    while True:
        try:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                break  # End of file

            headers = game.headers
            moves_uci = " ".join([move.uci() for move in game.mainline_moves()])  # Extract UCI moves

            games.append({
                "Event": headers.get("Event"),
                "Site": headers.get("Site"),
                "White": headers.get("White"),
                "Black": headers.get("Black"),
                "Result": headers.get("Result"),
                "UTCDate": headers.get("UTCDate"),
                "UTCTime": headers.get("UTCTime"),
                "WhiteElo": headers.get("WhiteElo"),
                "BlackElo": headers.get("BlackElo"),
                "WhiteRatingDiff": headers.get("WhiteRatingDiff"),
                "BlackRatingDiff": headers.get("BlackRatingDiff"),
                "ECO": headers.get("ECO"),
                "Opening": headers.get("Opening"),
                "TimeControl": headers.get("TimeControl"),
                "Termination": headers.get("Termination"),
                "Moves": moves_uci,  # Store UCI moves as a single string
            })

        except Exception as e:
            print(f"Error parsing game: {e}")
            continue  # Skip problematic games

# Convert to a pandas DataFrame
df = pd.DataFrame(games)

# Save to CSV
df.to_csv(output_csv_path, index=False, encoding="utf-8")

# Display DataFrame info
print(df.info())
print(df.head())

print(f"PGN conversion complete. Data saved to {output_csv_path}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121332 entries, 0 to 121331
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Event            121332 non-null  object
#  1   Site             121332 non-null  object
#  2   White            121332 non-null  object
#  3   Black            121332 non-null  object
#  4   Result           121332 non-null  object
#  5   UTCDate          121332 non-null  object
#  6   UTCTime          121332 non-null  object
#  7   WhiteElo         121332 non-null  object
#  8   BlackElo         121332 non-null  object
#  9   WhiteRatingDiff  121114 non-null  object
#  10  BlackRatingDiff  121114 non-null  object
#  11  ECO              121332 non-null  object
#  12  Opening          121332 non-null  object
#  13  TimeControl      121332 non-null  object
#  14  Termination      121332 non-null  object
#  15  Moves            121332 non-null  object
# dtypes: object(16)
# memory usage: 14.8+ MB
# None
#                   Event                          Site             White  \
# 0  Rated Classical game  https://lichess.org/j1dkb5dw             BFG9k
# 1  Rated Classical game  https://lichess.org/a9tcp02g    Desmond_Wilson
# 2  Rated Classical game  https://lichess.org/szom2tog     Kozakmamay007
# 3     Rated Bullet game  https://lichess.org/rklpc7mk  Naitero_Nagasaki
# 4     Rated Bullet game  https://lichess.org/1xb3os63      nichiren1967
#
#                Black Result     UTCDate   UTCTime WhiteElo BlackElo  \
# 0            mamalak    1-0  2012.12.31  23:01:03     1639     1403
# 1          savinka59    1-0  2012.12.31  23:04:12     1654     1919
# 2  VanillaShamanilla    1-0  2012.12.31  23:03:15     1643     1747
# 3                800    0-1  2012.12.31  23:04:57     1824     1973
# 4   Naitero_Nagasaki    0-1  2012.12.31  23:02:37     1765     1815
#
#   WhiteRatingDiff BlackRatingDiff  ECO  \
# 0              +5              -8  C00
# 1             +19             -22  D04
# 2             +13             -94  C50
# 3              -6              +8  B12
# 4              -9              +9  C00
#
#                                        Opening TimeControl Termination  \
# 0             French Defense: Normal Variation       600+8      Normal
# 1  Queen's Pawn Game: Colle System, Anti-Colle       480+2      Normal
# 2         Four Knights Game: Italian Variation      420+17      Normal
# 3         Caro-Kann Defense: Goldman Variation        60+1      Normal
# 4     French Defense: La Bourdonnais Variation        60+1      Normal
#
#                                                Moves
# 0  e2e4 e7e6 d2d4 b7b6 a2a3 c8b7 b1c3 g8h6 c1h6 g...
# 1  d2d4 d7d5 g1f3 g8f6 e2e3 c8f5 f3h4 f5g6 h4g6 h...
# 2  e2e4 e7e5 g1f3 b8c6 f1c4 g8f6 b1c3 f8c5 a2a3 c...
# 3  e2e4 c7c6 b1c3 d7d5 d1f3 d5e4 c3e4 b8d7 f1c4 g...
# 4  e2e4 e7e6 f2f4 d7d5 e4e5 c7c5 g1f3 d8b6 c2c3 b...
# PGN conversion complete. Data saved to chess_games.csv
